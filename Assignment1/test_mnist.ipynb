# %%
import numpy as np

from neural_network import NeuralNetwork
from utils import sigmoid, softmax, cross_entropy_loss, add_bias_dimension

# Only for testing
from keras.datasets import mnist

# %matplotlib inline
import matplotlib.pyplot as plt


(train_X, train_y), (test_X, test_y) = mnist.load_data()

subset = 2000

train_X = train_X[:subset,:]
train_y = train_y[:subset]
test_X = test_X[:int(subset/10),:]
test_y = test_y[:int(subset/10)]

# %%
print(train_X.shape)
print(train_y.shape)
print(test_X.shape)
print(test_y.shape)
# Out:
# (2000, 28, 28)
# (2000,)
# (200, 28, 28)
# (200,)

# %%
img = train_X[10]

plt.figure(figsize=(12, 8))
plt.imshow(img, cmap="gray")
plt.show()

# %%
plt.figure(figsize=(12, 8))

fig, ax = plt.subplots(1, 2)

fig.set_figheight(5)
fig.set_figwidth(15)

ax[0].hist(train_y)
ax[1].hist(test_y)
plt.show()

# %%
train_X = np.transpose(train_X.reshape(subset, 28*28))
test_X = np.transpose(test_X.reshape(int(subset / 10), 28*28))

# [pixels, batch size]
train_X.shape, test_X.shape
# Out:
# ((784, 2000), (784, 200))

# %%
nn = NeuralNetwork(layers_array=np.array([28*28, 10]), softmax=True)
output = nn.forward_pass(train_X, train_y)
output[:, 20]
# Out:
# array([5.e-05, 5.e-05, 5.e-05, 5.e-05, 5.e-05, 5.e-05, 5.e-05, 5.e-05,
#        5.e-05, 5.e-05])

# %%
loss = cross_entropy_loss(train_y, output)
loss
# Out:
# 444.7170274199741
