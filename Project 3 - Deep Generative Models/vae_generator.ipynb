# %%
import numpy as np
import matplotlib.pyplot as plt

from stacked_mnist import StackedMNISTData, DataMode
from models.vae import VAE
from models.mnist_classifier import MNISTClassifier

import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
import torch.nn.functional as F

from utils import *

# %%
model = VAE(in_channels=1)
model.load_state_dict(torch.load('trained_models/vae.pt', map_location=torch.device('cpu')))
model.eval()
# Out:
# VAE(
#   (encoder): Sequential(
#     (0): Conv2d(1, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(8, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (7): ReLU()
#     (8): Flatten(start_dim=1, end_dim=-1)
#     (9): Linear(in_features=256, out_features=128, bias=True)
#   )
#   (fc_mu): Linear(in_features=128, out_features=16, bias=True)
#   (fc_log_var): Linear(in_features=128, out_features=16, bias=True)
#   (decoder): Sequential(
#     (0): Linear(in_features=16, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=256, bias=True)
#     (3): ReLU()
#     (4): Unflatten(dim=1, unflattened_size=(64, 2, 2))
#     (5): ConvTranspose2d(64, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (6): ReLU()
#     (7): ConvTranspose2d(32, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (8): ReLU()
#     (9): ConvTranspose2d(16, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (10): ReLU()
#     (11): ConvTranspose2d(8, 1, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (12): Sigmoid()
#   )
# )

# %%
# Get latent variable
# Using the provided mnist dataset class
gen = StackedMNISTData(mode=DataMode.MONO_BINARY_COMPLETE, default_batch_size=9)
test_data = gen.get_full_data_set(training=False)

x_test, y_test = test_data

# Convert y_train and y_test into one-hot vectors
y_test = to_one_hot(y_test)

# Create pytorch dataloaders from x_test and y_test
x_test = torch.from_numpy(x_test.astype(np.float32)).permute(0, 3, 1, 2)
y_test = torch.from_numpy(y_test.astype(np.float32))

test_dataset = TensorDataset(x_test, y_test)
test_loader = DataLoader(dataset=test_dataset, batch_size=32)

# %% [markdown]
# Performance - Reconstruction Accuracy

# %%
mnist_classifier = MNISTClassifier(1)
mnist_classifier.load_state_dict(torch.load('trained_models/mnist_model.pt',  map_location=torch.device('cpu')))

correct_preds = 0

with torch.no_grad():
    for x, y in test_loader:
        rec, _, _ = model(x)

        rec_class = mnist_classifier(rec)
        rec_class = rec_class.argmax(dim=1, keepdim=True)
        truth = y.argmax(dim=1, keepdim=True)

        correct_preds += rec_class.eq(truth.view_as(rec_class)).sum().item()

    accuracy = correct_preds / len(test_loader.dataset)

print(f"Accuracy: {100*accuracy}%")
# Out:
# Accuracy: 94.19%

# %% [markdown]
# First, show some reconstructions

# %%
model.eval()

with torch.no_grad():

    x_show, y_show = next(iter(test_loader))

    reconstrustions, _, _ = model(x_show)

    # Create a figure with 5 horizontally arranged subplots
    fig, axs = plt.subplots(2, 4, figsize=(10, 6), dpi=150)

    # Plot each image in a separate subplot
    for i in range(2):
        for j in range(4):
            if i == 0:
                axs[i, j].imshow(x_show[j].squeeze(), cmap='gray')
            elif i == 1:
                axs[i, j].imshow(reconstrustions[j].squeeze(), cmap='gray')
        
    plt.show()

# %% [markdown]
# Now, let's generate an image

# %%
z = torch.normal(0, 1, size=(32, 16))

plt.figure(figsize=(6, 4), dpi=150)
plt.hist(z.detach().numpy())
plt.show()

# %%
model.eval()
with torch.no_grad():
    generated_images = model.decoder(z)

# %%
generated_images.shape
# Out:
# torch.Size([32, 1, 28, 28])

# %%
plt.imshow(generated_images[0].permute(1, 2, 0).squeeze(), cmap="gray")

# %%
model
# Out:
# VAE(
#   (encoder): Sequential(
#     (0): Conv2d(1, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(8, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (7): ReLU()
#     (8): Flatten(start_dim=1, end_dim=-1)
#     (9): Linear(in_features=256, out_features=128, bias=True)
#   )
#   (fc_mu): Linear(in_features=128, out_features=16, bias=True)
#   (fc_log_var): Linear(in_features=128, out_features=16, bias=True)
#   (decoder): Sequential(
#     (0): Linear(in_features=16, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=256, bias=True)
#     (3): ReLU()
#     (4): Unflatten(dim=1, unflattened_size=(64, 2, 2))
#     (5): ConvTranspose2d(64, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (6): ReLU()
#     (7): ConvTranspose2d(32, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (8): ReLU()
#     (9): ConvTranspose2d(16, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (10): ReLU()
#     (11): ConvTranspose2d(8, 1, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (12): Sigmoid()
#   )
# )

# %%
z = model.decoder[0:5](z)

c1 = model.decoder[5](z)
c1 = F.relu(c1)

c2 = model.decoder[7](c1)
c2 = F.relu(c2)

c3 = model.decoder[9](c2)
c3 = F.relu(c3)


c4 = model.decoder[11](c3)


c1.shape, c2.shape, c3.shape, c4.shape
# Out:
# (torch.Size([32, 32, 4, 4]),
#  torch.Size([32, 16, 7, 7]),
#  torch.Size([32, 8, 14, 14]),
#  torch.Size([32, 1, 28, 28]))

# %%
# Visualize som feature maps from c1
with torch.no_grad():
    # Create a figure with 5 horizontally arranged subplots
    fig, axs = plt.subplots(1, 5, figsize=(10, 6), dpi=150)

    # Plot each image in a separate subplot
    for i in range(5):
        axs[i].imshow(c1[0][i], cmap='gray')
        
    plt.show()

# %%
with torch.no_grad():
    # Create a figure with 5 horizontally arranged subplots
    fig, axs = plt.subplots(1, 5, figsize=(10, 6), dpi=150)

    # Plot each image in a separate subplot
    for i in range(5):
        axs[i].imshow(c2[0][i], cmap='gray')
        
    plt.show()

# %%
with torch.no_grad():
    # Create a figure with 5 horizontally arranged subplots
    fig, axs = plt.subplots(1, 5, figsize=(10, 6), dpi=150)

    # Plot each image in a separate subplot
    for i in range(5):
        axs[i].imshow(c3[0][i], cmap='gray')
        
    plt.show()

# %%
with torch.no_grad():    
    # Create a figure with 5 horizontally arranged subplots
    fig, axs = plt.subplots(1, 2, figsize=(6, 4), dpi=150)

    # Plot each image in a separate subplot
    axs[0].imshow(c4[0].squeeze(0), cmap='gray')
    axs[0].set_title('Final - No Sigmoid')
    axs[1].imshow(F.sigmoid(c4[0].squeeze(0)), cmap='gray')
    axs[1].set_title('Final - Sigmoid')

        
    plt.show()

# %% [markdown]
# Some more generated images

# %%
with torch.no_grad():    
    # Create a figure with 5 horizontally arranged subplots
    fig, axs = plt.subplots(2, 5, figsize=(10, 4), dpi=150)

    n = 0
    for i in range(2):
        for j in range(5):
            axs[i, j].imshow(generated_images[n].squeeze(), cmap="gray")
            axs[i, j].axis("off")
            n += 1

        
    plt.show()
